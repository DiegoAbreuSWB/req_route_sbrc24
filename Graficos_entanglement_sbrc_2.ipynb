# %%
import matplotlib.pyplot as plt
import numpy as np

# Data: Fidelity values for different routing scenarios and number of nodes
number_of_nodes = [4, 6, 8, 12, 16, 32, 48, 64]

avg_fidelity_routing_0 = [0.713251500000003, 0.737177500000002, 0.809486500000002, 0.901156500000003, 0.962286000000003, 0.965226000000003, 0.975250000000003, 0.975250000000003]
std_fidelity_routing_0 = [0.0408963485531106, 0.0402529979931621, 0.0344787677517267, 0.0202698861017397, 
                          0.0252785012821438, 0.0144703290909348, 0.0144330350238595, 0.0144330350238595]

avg_fidelity_routing_1 = [0.799118000000003, 0.817284500000003, 0.848666000000003, 0.952140000000003, 0.972229000000003, 0.975149000000003, 0.975247500000003, 0.975250000000003]
std_fidelity_routing_1 = [0.0364908851051877, 0.0351958595305969, 0.0321381177021929, 
                          0.0046918507683682, 0.0055296560100968, 0.0145737366176267, 0.0144371913386903, 0.0144330350238595]

avg_fidelity_routing_2 = [0.783757500000003, 0.798060000000003, 0.838934500000003, 0.961532500000003, 0.975235500000003, 0.975250000000003, 0.975250000000003, 0.975250000000003]
std_fidelity_routing_2 = [0.0376583203878972, 0.0369429298242574, 0.0332012943211181, 0.0126929376693302, 
                          0.0044542135638697, 0.0144330350238595, 0.0144330350238595, 0.0144330350238595]

avg_fidelity_routing_3 = [0.791040500000003, 0.838934500000003, 0.863701000000003, 0.958213500000003, 0.974085000000003, 0.975141500000003, 0.975234000000003, 0.975250000000003]
std_fidelity_routing_3 = [0.0372514835422364, 0.0332012943211181, 0.0304284114108838, 0.0126929376693302, 
                          0.0041490230460544, 0.0145679692390516, 0.0144558031253872, 0.0144330350238595]

# Additional routing data
avg_fidelity_additional = [0.815454937500003, 0.88399312500003, 0.901917500000003, 0.982396562500003, 0.983097187500003, 0.983970812500003, 0.985247687500003, 0.985250000000003]
std_fidelity_additional = [0.0371335630117738, 0.0351133612253241, 0.0319675926645999, 0.0129789309643649, 
                           0.0046332655702974, 0.0145249136268459, 0.0144420098293123, 0.0144330350238595]

# Creating the plot with error bars
#plt.figure(figsize=(10, 6))

plt.errorbar(number_of_nodes, avg_fidelity_routing_0, yerr=std_fidelity_routing_0, label='qDijkstra', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_1, yerr=std_fidelity_routing_1, label='R1:fidelidade', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_2, yerr=std_fidelity_routing_2, label='R2:eprs', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_3, yerr=std_fidelity_routing_3, label='R3:qubits', marker='o', capsize=5)
# Plot the additional data
plt.errorbar(number_of_nodes, avg_fidelity_additional, yerr=std_fidelity_additional, label='ReqRoute', marker='o', capsize=5)

# Adding titles and labels
plt.title('Cenário 2 - Configuração 1')
plt.xlabel('Tamanho da Rede')
plt.ylabel('Fidelidade Média da Rota')

# Set the y-axis limits between 0 and 1
plt.ylim(0, 1)

# Adding a legend
plt.legend()
plt.legend(loc='lower right')

# Showing a grid
plt.grid(True)

plt.savefig("cenario2_config1.pdf")

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data: Fidelity values for different routing scenarios and number of nodes
number_of_nodes = [4, 6, 8, 12, 16, 32, 48, 64]

avg_fidelity_routing_0 = [0.63688, 0.6095, 0.7801, 0.817431, 0.821254, 0.892197, 0.900777, 0.900636]
std_fidelity_routing_0 = [0.0389765974215297, 0.0380655334259222, 0.0307111383540239, 0.0219483204913269, 
                          0.0102024876789928, 0.0274444200339523, 0.0286553532695027, 0.0287880097262732]

avg_fidelity_routing_1 = [0.704838, 0.772351, 0.80091, 0.879232, 0.896651, 0.9025, 0.901184, 0.900752]
std_fidelity_routing_1 = [0.0368655961237574, 0.0314032482076297, 0.0284265319551999, 
                          0.00146117015354133, 0.0398855005554825, 0.027060007390982, 0.0283603974584279, 0.0286717717624845]

avg_fidelity_routing_2 = [0.687614, 0.746831, 0.797736, 0.87225, 0.901337, 0.902324, 0.900548, 0.9005]
std_fidelity_routing_2 = [0.0379860841630195, 0.0336664287442253, 0.0287451321625071, 0.0165799775331573, 
                          0.0395545374261917, 0.0272834936179369, 0.0288235961670296, 0.0288660700477221]

avg_fidelity_routing_3 = [0.701569, 0.777255, 0.810838, 0.881057, 0.901805, 0.902409, 0.901123, 0.900631]
std_fidelity_routing_3 = [0.0371298326469431, 0.0308225242274217, 0.0268690524127666, 
                          0.0137924739445105, 0.0392184519709792, 0.0272126022092706, 0.0283650818965855, 0.0288012645382108]

# Additional routing data
avg_fidelity_additional = [0.7693781625, 0.851869625, 0.884117, 0.90177475, 0.93033375, 0.9370117875, 0.9301046, 0.9300690875]
std_fidelity_additional = [0.0373271709779067, 0.0319640670597589, 0.0280135721768245, 0.014994717671027, 
                           0.0228861633175511, 0.0271853677393965, 0.0285163585073476, 0.0287797021161392]

# Creating the plot with error bars
#plt.figure(figsize=(10, 6))

plt.errorbar(number_of_nodes, avg_fidelity_routing_0, yerr=std_fidelity_routing_0, label='qDijkstra', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_1, yerr=std_fidelity_routing_1, label='R1:fidelidade', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_2, yerr=std_fidelity_routing_2, label='R2:eprs', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_3, yerr=std_fidelity_routing_3, label='R3:qubits', marker='o', capsize=5)
# Plot the additional data
plt.errorbar(number_of_nodes, avg_fidelity_additional, yerr=std_fidelity_additional, label='ReqRoute', marker='o', capsize=5)

# Adding titles and labels
plt.title('Cenário 2 - Configuração 2')
plt.xlabel('Tamanho da Rede')
plt.ylabel('Fidelidade Média da Rota')

# Set the y-axis limits between 0 and 1
plt.ylim(0, 1)

# Adding a legend
plt.legend()
plt.legend(loc='lower right')

# Showing a grid
plt.grid(True)

plt.savefig("cenario2_config2.pdf")

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data: Fidelity values for different routing scenarios and number of nodes
number_of_nodes = [4, 6, 8, 12, 16, 32, 48, 64]

avg_fidelity_routing_0 = [0.557499, 0.609419, 0.696834, 0.766478, 0.793414, 0.834823, 0.834587, 0.834512]
std_fidelity_routing_0 = [0.0393537660204205, 0.0372168753979965, 0.0211695525222933, 0.0230255153071544, 
                          0.0183493532866965, 0.0235715012462083, 0.0237202114450947, 0.0236924430145986]

avg_fidelity_routing_1 = [0.534316, 0.674167, 0.7316, 0.804495, 0.825885, 0.83444, 0.83461, 0.834832]
std_fidelity_routing_1 = [0.0401227765918561, 0.0330431564943484, 0.0274909737914102, 0.0159407120214249, 
                          0.0402164384965401, 0.0237810092300558, 0.0237047653437025, 0.0236149058012096]

avg_fidelity_routing_2 = [0.527562, 0.665588, 0.737555, 0.813326, 0.830808, 0.834924, 0.834619, 0.834179]
std_fidelity_routing_2 = [0.0403061824235439, 0.0335573381328138, 0.0269447837206017, 0.0134932033720685, 
                          0.0334209361015745, 0.0234976216668837, 0.0236943841236695, 0.0238247551718795]

avg_fidelity_routing_3 = [0.553088, 0.671805, 0.751769, 0.810533, 0.830409, 0.834977, 0.834791, 0.834528]
std_fidelity_routing_3 = [0.0395710237744742, 0.0331361462718585, 0.025163021209505, 0.0142036949104802, 
                          0.0334762610666381, 0.0235870403187852, 0.0237205674257595, 0.0237882999812933]

# Additional routing data
avg_fidelity_additional = [0.690307625, 0.764705875, 0.84060425, 0.86017, 0.9254685, 0.934884, 0.934721375, 0.934672375]
std_fidelity_additional = [0.0399999942632914, 0.0332455469663402, 0.0265329262405056, 0.0145458701013245, 
                           0.0323712118882509, 0.0236218904052416, 0.0237065722977105, 0.0237426536514608]

# Creating the plot with error bars
#plt.figure(figsize=(10, 6))

plt.errorbar(number_of_nodes, avg_fidelity_routing_0, yerr=std_fidelity_routing_0, label='qDijkstra', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_1, yerr=std_fidelity_routing_1, label='R1:fidelidade', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_2, yerr=std_fidelity_routing_2, label='R2:eprs', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_3, yerr=std_fidelity_routing_3, label='R3:qubits', marker='o', capsize=5)
# Plot the additional data
plt.errorbar(number_of_nodes, avg_fidelity_additional, yerr=std_fidelity_additional, label='ReqRoute', marker='o', capsize=5)

# Adding titles and labels
plt.title('Cenário 2 - Configuração 3')
plt.xlabel('Tamanho da Rede')
plt.ylabel('Fidelidade Média da Rota')

# Set the y-axis limits between 0 and 1
plt.ylim(0, 1)

# Adding a legend
plt.legend()
plt.legend(loc='lower right')

# Showing a grid
plt.grid(True)

plt.savefig("cenario2_config3.pdf")

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data: Fidelity values for different routing scenarios and number of nodes
number_of_nodes = [4, 6, 8, 12, 16, 32, 48, 64]

avg_fidelity_routing_0 = [0.131155, 0.270085, 0.54349, 0.6878, 0.74647, 0.792755, 0.792685, 0.792415]
std_fidelity_routing_0 = [0.0302202235225023, 0.037965071812786, 0.0368922105464012, 0.0270259430917776, 
                          0.0190009313192801, 0.0347215347443053, 0.0347392540938921, 0.0349748877768035]

avg_fidelity_routing_1 = [0.09739, 0.232575, 0.543235, 0.705535, 0.779415, 0.79177, 0.792135, 0.791755]
std_fidelity_routing_1 = [0.0268027961041381, 0.0366492352409979, 0.0368791688863781, 0.0249015539223961, 
                          0.0105157419020248, 0.034901534350226, 0.0349637923429367, 0.0352220807874833]

avg_fidelity_routing_2 = [0.099015, 0.23556, 0.530195, 0.72006, 0.78098, 0.79237, 0.792805, 0.79266]
std_fidelity_routing_2 = [0.0269925276280307, 0.0367593779055087, 0.0374148616160744, 0.0228920829982769, 
                          0.0393687053352312, 0.0349547292937594, 0.0348181989051703, 0.034971765754677]

avg_fidelity_routing_3 = [0.10336, 0.242385, 0.537285, 0.72325, 0.77652, 0.79185, 0.792215, 0.79293]
std_fidelity_routing_3 = [0.0275218931761607, 0.0371104819121229, 0.0371497649757034, 0.022437677575899, 
                          0.0113464486073837, 0.0347581285457086, 0.0344654722149574, 0.0345205026035254]

# Additional routing data
avg_fidelity_additional = [0.31194425, 0.457618125, 0.641020625, 0.816205625, 0.845913125, 0.82470625, 0.8226325, 0.822685]
std_fidelity_additional = [0.0271057389694432, 0.0368396983528765, 0.037147931826052, 0.0320866871603548,
                           0.0204102986148799, 0.0348714640632313, 0.0347491544876882, 0.0349047830485619]

# Creating the plot with error bars
#plt.figure(figsize=(10, 6))

plt.errorbar(number_of_nodes, avg_fidelity_routing_0, yerr=std_fidelity_routing_0, label='qDijkstra', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_1, yerr=std_fidelity_routing_1, label='R1:fidelidade', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_2, yerr=std_fidelity_routing_2, label='R2:eprs', marker='o', capsize=5)
plt.errorbar(number_of_nodes, avg_fidelity_routing_3, yerr=std_fidelity_routing_3, label='R3:qubits', marker='o', capsize=5)
# Plot the additional data
plt.errorbar(number_of_nodes, avg_fidelity_additional, yerr=std_fidelity_additional, label='ReqRoute', marker='o', capsize=5)

# Adding titles and labels
plt.title('Cenário 2 - Configuração 4')
plt.xlabel('Tamanho da Rede')
plt.ylabel('Fidelidade Média da Rota')

# Set the y-axis limits between 0 and 1
plt.ylim(0, 1)

# Adding a legend
plt.legend()
plt.legend(loc='lower right')

# Showing a grid
plt.grid(True)

plt.savefig("cenario2_config4.pdf")

# Display the plot
plt.show()
